# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import openpyxl
df = pd.read_excel('data/canadian_immegration_data.xlsx')

# %%
grupos=df.groupby('Continent').sum()
grupos.drop(columns={'2013','Country','Region'})
# Out:
#                                   1980   1981   1982   1983   1984   1985  \
# Continent
# Africa                            3951   4363   3819   2671   2639   2650
# Asia                             31025  34314  30214  24696  27274  23850
# Europe                           39760  44802  42720  24638  22287  20844
# Latin America and the Caribbean  13081  15215  16769  15427  13678  15171
# Northern America                  9378  10030   9074   7100   6661   6543
# Oceania                           1942   1839   1675   1018    878    920
#
#                                   1986   1987   1988   1989  ...    2004  \
# Continent                                                    ...
# Africa                            3782   7494   7552   9894  ...   28192
# Asia                             28739  43203  47454  60256  ...  134850
# Europe                           24370  46698  54726  60893  ...   38082
# Latin America and the Caribbean  21179  28471  21924  25060  ...   22181
# ...

# %%
fig, axs1=plt.subplot(2,2,1)

axs1[0].plot(grupos[0])
axs1[0].set_title('titulo')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 fig, axs1=plt.subplot(2,2,1)
#       3 axs1[0].plot(grupos[0])
#       4 axs1[0].set_title('titulo')
#
# TypeError: cannot unpack non-iterable Axes object
