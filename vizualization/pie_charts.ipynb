# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import openpyxl
df = pd.read_excel('data/canadian_immegration_data.xlsx')

# %%
df_count=df.groupby('Continent').sum()

# %%
df_count['Total'].plot(kind='pie')
plt.title('Total de migrantes por zona')
plt.show()
