# %%
from pywaffle import Waffle
import pandas as pd
import matplotlib.pyplot as mpl
import openpyxl

# %%
df = pd.read_excel('data/canadian_immegration_data.xlsx')

# %%
#datos
grupo = df.groupby(df['Continent']).value_counts()

# %%
mpl.figure(FigureClass=Waffle, values=grupo, rows=20, columns=20)
# Out:
# <Waffle size 640x480 with 1 Axes>
# <Waffle size 640x480 with 1 Axes>
