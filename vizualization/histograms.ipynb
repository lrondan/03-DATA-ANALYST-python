# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import openpyxl
df = pd.read_excel('data/canadian_immegration_data.xlsx')

# %%
df['2013'].plot(kind='hist')
plt.title('Histograma 2013')
plt.ylabel('paises')
plt.xlabel('inmigrantes')
plt.show()

# %%
import numpy as np

# %%
count, bins_edge = np.histogram(df['2013'])

# %%
df['2013'].plot(kind='hist', xticks = bins_edge)
plt.title('Histograma 2013')
plt.ylabel('paises')
plt.xlabel('inmigrantes')
plt.show()
