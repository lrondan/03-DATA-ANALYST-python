# %%
import pandas as pd
import matplotlib.pyplot as plt

d = {'size':['X', 'XL', 'L', 'M'], 'price':[23, 54, 65, 54]}
df = pd.DataFrame(data=d)

y = df['price']
x = df['size']
plt.scatter(x,y)
plt.title('Titulo')
plt.ylim(0,)
# Out:
# (0.0, 67.1)
