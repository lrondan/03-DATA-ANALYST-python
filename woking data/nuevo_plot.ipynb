# %%
import pandas as pd
import matplotlib.pyplot as mpl

with open('new_data.csv', 'r') as file2:
    vizual = pd.read_csv(file2)
    xvalors = ['motor', 'Ships']
    yvalors = [9420,9441.38]
    mpl.plot(xvalors, yvalors, linestyle='--')
    mpl.xlabel('Producto')
    mpl.ylabel('Unidades vendidas')
    mpl.title('resumen')
    mpl.show()
